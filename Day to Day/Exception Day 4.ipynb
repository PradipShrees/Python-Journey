# %%
try:
    x = int(input("Enter A NUMBER:"))
    print(f"x is {x}")
except ValueError:
    print("Please enter a number")

# %%
try:
    x = int(input("Enter A NUMBER:"))
except ValueError:
    print("x is not an integer")
else:
    print(f"x is {x}")

#handeling error by adding else statement which fill force to
# give either of one result

# %%
while True:
    try:
        x = int(input("Enter A NUMBER:"))
    except ValueError:
        print("x is not an integer")
        print("x should be a number like 1,2,3")
    else:
        break
print(f"x is {x}")

#handeling error by adding else statement which fill force to
# give either of one result
#make a infinte loop with While loop to ask user again until you get
#user to type right answer

# %%
while True:
    try:
        x = int(input("Enter A NUMBER:"))
        break
    except ValueError:
        print("x is not an integer")
        print("x should be a number like 1,22,333")

print(f"x is {x}")

#handeling error by adding else statement which fill force to
# give either of one result
#make a infinte loop with While loop to ask user again until you get
#user to type right answer

# %%
def main():
    x = get_int()
    print(f"x is {x}")

def get_int():
    while True:
        try:
            x = int(input("Enter A NUMBER:"))

        except ValueError:
            print("x is not an integer")
            print("x should be a number like 1,22,333")
        else:
            break
    return x
main()
#handeling error by adding else statement which fill force to
# give either of one result
#make a infinte loop with While loop to ask user again until you get
#user to type right answer

# %%
def main():
    x = get_int()
    print(f"x is {x}")

def get_int():
    while True:
        try:
            return int(input("Enter A NUMBER:"))

        except ValueError:
            print("x is not an integer")
            print("x should be a number like 1,22,333")
main()
#handeling error by adding else statement which fill force to
# give either of one result
#make a infinte loop with While loop to ask user again until you get
#user to type right answer
# return will break and return x to main function

# %%
def main():
    x = get_int()
    print(f"x is {x}")

def get_int():
    while True:
        try:
            return int(input("Enter A NUMBER:"))

        except ValueError:
            pass
        #pass will not show anything but will transfer process to enter again
main()
#handeling error by adding else statement which fill force to
# give either of one result
#make a infinte loop with While loop to ask user again until you get
#user to type right answer
# return will break and return x to main function
