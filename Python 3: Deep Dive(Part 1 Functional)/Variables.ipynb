# %%
s = "ArithmeticError"
for i in range(len(s)):
    print(i, s[i] )
# Out:
# 0 A
# 1 r
# 2 i
# 3 t
# 4 h
# 5 m
# 6 e
# 7 t
# 8 i
# 9 c
# 10 E
# 11 r
# 12 r
# 13 o
# 14 r

# %%
s = "ArithmeticError"
for i ,c in enumerate(s): #enumerate() function returns both the index and the character
    print(i, c)
# Out:
# 0 A
# 1 r
# 2 i
# 3 t
# 4 h
# 5 m
# 6 e
# 7 t
# 8 i
# 9 c
# 10 E
# 11 r
# 12 r
# 13 o
# 14 r

# %%
s = "hello"
i = 0
for c in s:
    print(i, c)
    i += 1
# Out:
# 0 h
# 1 e
# 2 l
# 3 l
# 4 o

# %%
for i in range (5): #upto 4 , 5 isn't included
    print("--------")
    try:
        10 / (i-3)
    except ZeroDivisionError:     
        print("Divided by zero!")
        continue
    finally:
        print("always runs")
    print(i)
# Out:
# --------
# always runs
# 0
# --------
# always runs
# 1
# --------
# always runs
# 2
# --------
# Divided by zero!
# always runs
# --------
# always runs
# 4
